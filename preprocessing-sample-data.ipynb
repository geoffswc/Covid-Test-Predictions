# %%
import pandas as pd

# %%
headers = ['R', 'temperature', 'cough_severity', 'difficult_breathing', 'exposure_risk', 'days_since_onset']

# %%
rows = [
    ('Pos', 103.2, 'Severe', 1, 1, 15), 
    ('Neg', 97.5, 'Mild', 0, 1, 7), 
    ('Neg', 98.5, 'None', 0, 1, 0), 
    ('Pos', 101.3, 'Mild', 1, 1, 4), 
    ('Neg', 98.5, 'None', 0, 0, 21), 
    ('Pos', 99.0, 'Mild', 0, 1, 10), 
    ('Neg', 98.1, 'Mild', 0, 1, 5), 
    ('Neg', 102.1, 'Severe', 1, 0, 4)]

# %%
df = pd.DataFrame(rows, columns=headers)

# %%
df
# Out:
#      R  temperature cough_severity  difficult_breathing  exposure_risk  \
# 0  Pos        103.2         Severe                    1              1
# 1  Neg         97.5           Mild                    0              1
# 2  Neg         98.5           None                    0              1
# 3  Pos        101.3           Mild                    1              1
# 4  Neg         98.5           None                    0              0
# 5  Pos         99.0           Mild                    0              1
# 6  Neg         98.1           Mild                    0              1
# 7  Neg        102.1         Severe                    1              0
#
#    days_since_onset
# 0                15
# 1                 7
# 2                 0
# 3                 4
# 4                21
# 5                10
# 6                 5
# 7                 4

# %%
#https://scikit-learn.org/stable/modules/preprocessing.html

# %%
# encoding categorical features

# %%
from sklearn.preprocessing import OrdinalEncoder

# this allows us to control the order of the encoding
# otherwise, the encoder will order them in the order they are first observed

enc = OrdinalEncoder(categories=[['None', 'Mild', 'Moderate', 'Severe']])
enc.fit_transform(df.loc[:,['cough_severity']])

df['cough_severity'] = enc.fit_transform(df.loc[:,['cough_severity']]).astype('int')

# %%
df
# Out:
#      R  temperature  cough_severity  difficult_breathing  exposure_risk  \
# 0  Pos        103.2               3                    1              1
# 1  Neg         97.5               1                    0              1
# 2  Neg         98.5               0                    0              1
# 3  Pos        101.3               1                    1              1
# 4  Neg         98.5               0                    0              0
# 5  Pos         99.0               1                    0              1
# 6  Neg         98.1               1                    0              1
# 7  Neg        102.1               3                    1              0
#
#    days_since_onset
# 0                15
# 1                 7
# 2                 0
# 3                 4
# 4                21
# 5                10
# 6                 5
# 7                 4

# %%
df.iloc[:,0]
# Out:
# 0    Pos
# 1    Neg
# 2    Neg
# 3    Pos
# 4    Neg
# 5    Pos
# 6    Neg
# 7    Neg
# Name: R, dtype: object

# %%
# more ordinal encoding, map neg test result to 0, pos result to 1

enc = OrdinalEncoder(categories=[['Neg', 'Pos']])
enc.fit_transform(df.loc[:,['R']])

df['R'] = enc.fit_transform(df.loc[:,['R']]).astype('int')

# %%
df
# Out:
#    R  temperature  cough_severity  difficult_breathing  exposure_risk  \
# 0  1        103.2               3                    1              1
# 1  0         97.5               1                    0              1
# 2  0         98.5               0                    0              1
# 3  1        101.3               1                    1              1
# 4  0         98.5               0                    0              0
# 5  1         99.0               1                    0              1
# 6  0         98.1               1                    0              1
# 7  0        102.1               3                    1              0
#
#    days_since_onset
# 0                15
# 1                 7
# 2                 0
# 3                 4
# 4                21
# 5                10
# 6                 5
# 7                 4

# %%
# binarization
# we will create a column, 'fever', based on the temperature
# fever will be recorded as binary - present or not. 
# convert temperature to binary indicator based on a threshold of 101

# %%
from sklearn.preprocessing import Binarizer

# %%
binarizer = Binarizer(threshold=(101.0)).fit([df['temperature']])

# %%
df['fever'] = binarizer.transform([df['temperature']]).astype('int')[0]

# %%
df
# Out:
#    R  temperature  cough_severity  difficult_breathing  exposure_risk  \
# 0  1        103.2               3                    1              1
# 1  0         97.5               1                    0              1
# 2  0         98.5               0                    0              1
# 3  1        101.3               1                    1              1
# 4  0         98.5               0                    0              0
# 5  1         99.0               1                    0              1
# 6  0         98.1               1                    0              1
# 7  0        102.1               3                    1              0
#
#    days_since_onset  fever
# 0                15      1
# 1                 7      0
# 2                 0      0
# 3                 4      1
# 4                21      0
# 5                10      0
# 6                 5      0
# 7                 4      1

# %%
# scaling and standardization 
# we will use the minmax scaler here (divide each observation by max(abs(x)))
# standard scalar will normalize as well as scale, using unit variance
# note that minmax will preserve binary data

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
scaler = MinMaxScaler().fit(df)

# %%
X_scaled = scaler.transform(df)

# %%
X_scaled
# Out:
# array([[1.        , 1.        , 1.        , 1.        , 1.        ,
#         0.71428571, 1.        ],
#        [0.        , 0.        , 0.33333333, 0.        , 1.        ,
#         0.33333333, 0.        ],
#        [0.        , 0.1754386 , 0.        , 0.        , 1.        ,
#         0.        , 0.        ],
#        [1.        , 0.66666667, 0.33333333, 1.        , 1.        ,
#         0.19047619, 1.        ],
#        [0.        , 0.1754386 , 0.        , 0.        , 0.        ,
#         1.        , 0.        ],
#        [1.        , 0.26315789, 0.33333333, 0.        , 1.        ,
#         0.47619048, 0.        ],
#        [0.        , 0.10526316, 0.33333333, 0.        , 1.        ,
#         0.23809524, 0.        ],
#        [0.        , 0.80701754, 1.        , 1.        , 0.        ,
#         0.19047619, 1.        ]])

# %%
#minmax scaler
df.iloc[:,1:]
# Out:
#    temperature  cough_severity  difficult_breathing  exposure_risk  \
# 0        103.2               3                    1              1
# 1         97.5               1                    0              1
# 2         98.5               0                    0              1
# 3        101.3               1                    1              1
# 4         98.5               0                    0              0
# 5         99.0               1                    0              1
# 6         98.1               1                    0              1
# 7        102.1               3                    1              0
#
#    days_since_onset  fever
# 0                15      1
# 1                 7      0
# 2                 0      0
# 3                 4      1
# 4                21      0
# 5                10      0
# 6                 5      0
# 7                 4      1

# %%
df = pd.DataFrame(X_scaled, columns=df.columns)

# %%
df
# Out:
#      R  temperature  cough_severity  difficult_breathing  exposure_risk  \
# 0  1.0     1.000000        1.000000                  1.0            1.0
# 1  0.0     0.000000        0.333333                  0.0            1.0
# 2  0.0     0.175439        0.000000                  0.0            1.0
# 3  1.0     0.666667        0.333333                  1.0            1.0
# 4  0.0     0.175439        0.000000                  0.0            0.0
# 5  1.0     0.263158        0.333333                  0.0            1.0
# 6  0.0     0.105263        0.333333                  0.0            1.0
# 7  0.0     0.807018        1.000000                  1.0            0.0
#
#    days_since_onset  fever
# 0          0.714286    1.0
# 1          0.333333    0.0
# 2          0.000000    0.0
# 3          0.190476    1.0
# 4          1.000000    0.0
# 5          0.476190    0.0
# 6          0.238095    0.0
# 7          0.190476    1.0

# %%
# convert our Result to pure integer form
df['R'] = df['R'].astype('int')

# %%
df
# Out:
#    R  temperature  cough_severity  difficult_breathing  exposure_risk  \
# 0  1     1.000000        1.000000                  1.0            1.0
# 1  0     0.000000        0.333333                  0.0            1.0
# 2  0     0.175439        0.000000                  0.0            1.0
# 3  1     0.666667        0.333333                  1.0            1.0
# 4  0     0.175439        0.000000                  0.0            0.0
# 5  1     0.263158        0.333333                  0.0            1.0
# 6  0     0.105263        0.333333                  0.0            1.0
# 7  0     0.807018        1.000000                  1.0            0.0
#
#    days_since_onset  fever
# 0          0.714286    1.0
# 1          0.333333    0.0
# 2          0.000000    0.0
# 3          0.190476    1.0
# 4          1.000000    0.0
# 5          0.476190    0.0
# 6          0.238095    0.0
# 7          0.190476    1.0
